# %% [markdown]
# The Reinforcement Learning Algorithm implemented in this Assignment is PPO, Proximal Policy Optimization with CNN, Convolutional Neural Network Policy

# %%
#pip install gym_super_mario_bros==7.3.0 nes_py

# %%
#Import the game
import gym_super_mario_bros
#import the joypad wrapper
from nes_py.wrappers import JoypadSpace
#Import thje SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
#sIMPLE ACTIONS is a libraary that simplifies the actions that the ai can take to make it less complicated
SIMPLE_MOVEMENT
# Out:
# [['NOOP'],
#  ['right'],
#  ['right', 'A'],
#  ['right', 'B'],
#  ['right', 'A', 'B'],
#  ['A'],
#  ['left']]

# %%
env = gym_super_mario_bros.make('SuperMarioBros-v0')# setup which emulatiuon version to use https://github.com/Kautenja/gym-super-mario-bros
#env.action_space
env = JoypadSpace(env,SIMPLE_MOVEMENT)#SIMPLIFY THE NUMBER OF ACTIONS the ai can take from 256 to 7
#env.action_space#tells the number of actions available

#observation space shows what output the game returns,  i.e the number of pixles in a frame of the game
env.observation_space.shape
# Out:
# (240, 256, 3)

# %%
# #create a flag for restarting the game
# done = True
# for frame in range(100000): # for every frame of the game
#     if done:#if the game isnt started we start if via  start =  True
#         env.reset()#resets game environment to start
#     state, reward, done, info = env.step(env.action_space.sample())#parses a random action to the game
#     env.render()#this shows the game on the screen
# env.close()# this runs the game
# Out:
# C:\Users\Computing\AppData\Local\Programs\Python\Python310\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# C:\Users\Computing\AppData\Local\Programs\Python\Python310\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256

# %%
#prints random actions from the simple movement function
#SIMPLE_MOVEMENT[env.action_space.sample()]
#prints a random number from the action_ space
#env.action_space.sample()
#Shows all available movements
#SIMPLE_MOVEMENT
#state = env.reset()#returns a state showing a particular frame from the game
#env.step(1)[1] #shoes the rewards for eah step
#based on the youtube tutorial Build an Mario AI Model with Python
# Out:
# 5

# %%
#nstall pytorch https://pytorch.org/get-started/locally/
#!pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113

# %%
#install stable baselines AI library https://stable-baselines3.readthedocs.io/en/master/guide/install.html
#!pip install stable-baselines3[extra]

# %%
#Preprocessing the environment for AI training
#import frame stacker Wrapper and Grayscaling Wrapper
from gym.wrappers import GrayScaleObservation # allows us to capture multiple frame while playing the game
#Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv #converts the game into grayscale to cut down information
#Import Matplotlib
from matplotlib import pyplot as plt

# %%
# 1. create the base environment
#the AI library i will use is the Stable Baselines 

env = gym_super_mario_bros.make('SuperMarioBros-v0')# setup which emulatiuon version to use https://github.com/Kautenja/gym-super-mario-bros
# 2. simplify the controls
env = JoypadSpace(env,SIMPLE_MOVEMENT)#SIMPLIFY THE NUMBER OF ACTIONS the ai can take from 256 to 7
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)# required to keep the last dimention which determins colour to do frame stacking
# 4. Wrap inside dummy environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last') #by parsing the env to the frame stack we can specify how many frames to stack, last argument specifies where the rgb channel is,

# %%
state = env.reset()

# %%
state, reward, done, info = env.step([env.action_space.sample()])#parses a random action to the game, this has to be in an array because the environment is now vectorised

# %%
plt.imshow(state[0])#show the frame in colored form before processing

# %%
plt.figure(figsize=(20,16))
for idx in range(state.shape[3]):
    plt.subplot(1,4,idx+1)
    plt.imshow(state[0][:,:,idx])
plt.show()

# %%
#Train the RL Model
#Import os for file path management
import os
#import PPO for algos
from stable_baselines3 import PPO
#import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
# Create a class to save models after x amount of steps
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):#check frequency, how often to save the model, save_path, where to save the model
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = '../../../train/'#CREATE THESE ON THE DESKTOP IF THE GIT REPO IS CLONES ON THE DESKTOP
LOG_DIR = '../../..//logs/'
print(os.getcwd())

# %%
#Setup callback Saves the model every 10,thousand steps at the desired location
callback = TrainAndLoggingCallback(check_freq=1000,save_path=CHECKPOINT_DIR)

# %%
#CREATING AN AI MODEL
#Setup the MODEL: Machine learning/Deep Learning/ Reinforcement Learning, Ai model
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001,n_steps=512)#using the CNN cLassifier, tensorboard allows us to see how the training is performing, learning rate determines how fast the ai is learning
#n_steps is how many frames to wait per game before updating the neural network

# %%
#Train the AI model, this is where it starts to learn ,  how many frames the AI sees for every single game
model.learn(total_timesteps=1000000,callback=callback) # can remove callback to prevent saving the data

#LOSS should be going down and explained_variance should be going up
# Out:
# C:\Users\Computing\AppData\Local\Programs\Python\Python310\lib\site-packages\flatbuffers\compat.py:19: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# Logging to ../../../..//logs/PPO_1
# C:\Users\Computing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\image\utils.py:23: DeprecationWarning: NEAREST is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   'nearest': pil_image.NEAREST,
# C:\Users\Computing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\image\utils.py:24: DeprecationWarning: BILINEAR is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BILINEAR instead.
#   'bilinear': pil_image.BILINEAR,
# C:\Users\Computing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\image\utils.py:25: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   'bicubic': pil_image.BICUBIC,
# C:\Users\Computing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\image\utils.py:28: DeprecationWarning: HAMMING is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.HAMMING instead.
#   if hasattr(pil_image, 'HAMMING'):
# C:\Users\Computing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\image\utils.py:30: DeprecationWarning: BOX is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BOX instead.
#   if hasattr(pil_image, 'BOX'):
# C:\Users\Computing\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\image\utils.py:33: DeprecationWarning: LANCZOS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   if hasattr(pil_image, 'LANCZOS'):
# C:\Users\Computing\AppData\Local\Programs\Python\Python310\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ----------------------------
# | time/              |     |
# |    fps             | 83  |
# |    iterations      | 1   |
# |    time_elapsed    | 6   |
# |    total_timesteps | 512 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 2            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 8.259434e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.000857    |
# |    learning_rate        | 1e-06        |
# |    loss                 | 153          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -2.34e-05    |
# |    value_loss           | 457          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 5.98646e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.0592      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.28        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.000579   |
# |    value_loss           | 2.08        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 86           |
# |    iterations           | 4            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 8.082134e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0617       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.117        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -7.22e-05    |
# |    value_loss           | 0.859        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 89            |
# |    iterations           | 5             |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 1.4432357e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00103       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.125         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00019      |
# |    value_loss           | 0.578         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 88            |
# |    iterations           | 6             |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 1.2337929e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00837      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.157         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000218     |
# |    value_loss           | 0.492         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 7           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 9.99216e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.00475     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.185       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000139   |
# |    value_loss           | 0.582       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 89           |
# |    iterations           | 8            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 9.083422e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00789      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0817       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00015     |
# |    value_loss           | 0.257        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 9            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 6.855116e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0151       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.144        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -8.3e-05     |
# |    value_loss           | 0.37         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 89            |
# |    iterations           | 10            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 1.8038903e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00456      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.229         |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.0003       |
# |    value_loss           | 0.541         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 11           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 9.867828e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00466     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.116        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000142    |
# |    value_loss           | 0.266        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 12            |
# |    time_elapsed         | 68            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 2.2472814e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00311      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0643        |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000346     |
# |    value_loss           | 0.151         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 13            |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 3.5056844e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00418      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.101         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000451     |
# |    value_loss           | 0.225         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 14            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 2.0650565e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00863      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0718        |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000232     |
# |    value_loss           | 0.153         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 15            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 1.6748905e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 9.13e-05      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0945        |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000262     |
# |    value_loss           | 0.196         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 16            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.6704085e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00505      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.172         |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000256     |
# |    value_loss           | 0.259         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 17            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 8704          |
# | train/                  |               |
# |    approx_kl            | 1.9708648e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0192        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 91.4          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000325     |
# |    value_loss           | 205           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 18           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 2.827798e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00218      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 74.6         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -1.05e-05    |
# |    value_loss           | 199          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 19            |
# |    time_elapsed         | 106           |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 4.1882857e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0361        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.225         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000203     |
# |    value_loss           | 1.7           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 20            |
# |    time_elapsed         | 112           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 3.0173454e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.122         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.225         |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00024      |
# |    value_loss           | 1.22          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 21            |
# |    time_elapsed         | 117           |
# |    total_timesteps      | 10752         |
# | train/                  |               |
# |    approx_kl            | 3.9232895e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00518       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.171         |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000409     |
# |    value_loss           | 0.787         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 22            |
# |    time_elapsed         | 123           |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 2.8447714e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00844       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 20.8          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000212     |
# |    value_loss           | 65.9          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 23            |
# |    time_elapsed         | 129           |
# |    total_timesteps      | 11776         |
# | train/                  |               |
# |    approx_kl            | 2.6002992e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0448        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.226         |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000236     |
# |    value_loss           | 0.869         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 24            |
# |    time_elapsed         | 135           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 3.7738704e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.000495     |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.126         |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000351     |
# |    value_loss           | 0.668         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 25            |
# |    time_elapsed         | 140           |
# |    total_timesteps      | 12800         |
# | train/                  |               |
# |    approx_kl            | 2.4065725e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0175       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.112         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000285     |
# |    value_loss           | 0.549         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 26            |
# |    time_elapsed         | 146           |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 5.6375517e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0107        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.218         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.00073      |
# |    value_loss           | 0.616         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 27            |
# |    time_elapsed         | 151           |
# |    total_timesteps      | 13824         |
# | train/                  |               |
# |    approx_kl            | 5.0113187e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00156       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.15          |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000522     |
# |    value_loss           | 0.41          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 28            |
# |    time_elapsed         | 157           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 5.7116267e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00451      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0736        |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000657     |
# |    value_loss           | 0.225         |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 91             |
# |    iterations           | 29             |
# |    time_elapsed         | 162            |
# |    total_timesteps      | 14848          |
# | train/                  |                |
# |    approx_kl            | 1.22095225e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.94          |
# |    explained_variance   | -0.000204      |
# |    learning_rate        | 1e-06          |
# |    loss                 | 0.073          |
# |    n_updates            | 280            |
# |    policy_gradient_loss | -0.000148      |
# |    value_loss           | 0.238          |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 30            |
# |    time_elapsed         | 168           |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 2.1713902e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00191       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0879        |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000236     |
# |    value_loss           | 0.22          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 31            |
# |    time_elapsed         | 173           |
# |    total_timesteps      | 15872         |
# | train/                  |               |
# |    approx_kl            | 2.2619613e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00626       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.157         |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000274     |
# |    value_loss           | 0.242         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 32            |
# |    time_elapsed         | 180           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 4.1518128e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00983      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0808        |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000483     |
# |    value_loss           | 0.16          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 33           |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 16896        |
# | train/                  |              |
# |    approx_kl            | 8.259551e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0288       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 144          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 6.7e-05      |
# |    value_loss           | 327          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 34            |
# |    time_elapsed         | 191           |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 1.7750193e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0666        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 25.9          |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000144     |
# |    value_loss           | 64.8          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 35            |
# |    time_elapsed         | 196           |
# |    total_timesteps      | 17920         |
# | train/                  |               |
# |    approx_kl            | 2.5115209e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0577        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0922        |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -7.43e-05     |
# |    value_loss           | 0.888         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 36           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 2.999825e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.113       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0524       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000237    |
# |    value_loss           | 0.67         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 37            |
# |    time_elapsed         | 207           |
# |    total_timesteps      | 18944         |
# | train/                  |               |
# |    approx_kl            | 7.8457175e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.181         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.104         |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000663     |
# |    value_loss           | 0.424         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 38            |
# |    time_elapsed         | 213           |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 6.3568586e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00967       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.101         |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -1.86e-05     |
# |    value_loss           | 0.454         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 39            |
# |    time_elapsed         | 218           |
# |    total_timesteps      | 19968         |
# | train/                  |               |
# |    approx_kl            | 2.5815214e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.137         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0762        |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000237     |
# |    value_loss           | 0.309         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 40            |
# |    time_elapsed         | 225           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 2.5675166e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0494        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.121         |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000259     |
# |    value_loss           | 0.355         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 41            |
# |    time_elapsed         | 230           |
# |    total_timesteps      | 20992         |
# | train/                  |               |
# |    approx_kl            | 2.7627568e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0449        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 30            |
# |    n_updates            | 400           |
# |    policy_gradient_loss | 3.38e-05      |
# |    value_loss           | 67.9          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 42            |
# |    time_elapsed         | 236           |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 2.0877691e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0754        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0959        |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000241     |
# |    value_loss           | 0.416         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 43            |
# |    time_elapsed         | 242           |
# |    total_timesteps      | 22016         |
# | train/                  |               |
# |    approx_kl            | 2.9228744e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00627       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0976        |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000287     |
# |    value_loss           | 0.351         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 44            |
# |    time_elapsed         | 247           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.1008233e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0169        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.112         |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -6.34e-05     |
# |    value_loss           | 0.314         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 45            |
# |    time_elapsed         | 253           |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 1.2912205e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0657        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0988        |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.00013      |
# |    value_loss           | 0.25          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 46            |
# |    time_elapsed         | 259           |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 3.8295402e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0138        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0798        |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000463     |
# |    value_loss           | 0.266         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 47            |
# |    time_elapsed         | 265           |
# |    total_timesteps      | 24064         |
# | train/                  |               |
# |    approx_kl            | 4.0337443e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00393      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0583        |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000396     |
# |    value_loss           | 0.173         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 48            |
# |    time_elapsed         | 270           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 2.2478634e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00218      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 15.5          |
# |    n_updates            | 470           |
# |    policy_gradient_loss | 5.29e-05      |
# |    value_loss           | 11.5          |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 90             |
# |    iterations           | 49             |
# |    time_elapsed         | 276            |
# |    total_timesteps      | 25088          |
# | train/                  |                |
# |    approx_kl            | 0.000112621114 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.94          |
# |    explained_variance   | 0.0766         |
# |    learning_rate        | 1e-06          |
# |    loss                 | 147            |
# |    n_updates            | 480            |
# |    policy_gradient_loss | 0.000258       |
# |    value_loss           | 482            |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 50            |
# |    time_elapsed         | 281           |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 1.5646685e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0343       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0913        |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -4.13e-05     |
# |    value_loss           | 1.04          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 90            |
# |    iterations           | 51            |
# |    time_elapsed         | 288           |
# |    total_timesteps      | 26112         |
# | train/                  |               |
# |    approx_kl            | 5.7490543e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.391         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.102         |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000498     |
# |    value_loss           | 0.462         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 52           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 1.774833e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0225       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0587       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -9.5e-05     |
# |    value_loss           | 0.313        |
# ------------------------------------------

# %%
model.save('../../../mario_testmodel')

# %%
#Test out the model


# Load model
model = PPO.load('../../../train/best_model_1000000')

# %%
state = env.reset()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 state = env.reset()
#
# NameError: name 'env' is not defined

# %%
# Start the game 
state = env.reset()
# Loop through the game
while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
